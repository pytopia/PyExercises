# %% [markdown]
# # 23 - Advanced Exercises
#
# *   Error Handling

# %% [markdown]
# ## 🍋🍋🍋
# 1.Can you modify the following code to get the **```SyntaxError:```** ?
#
# Do you think **```SyntaxError:```** can be handled using (try: ... except:) syntax?

# %%
# Write your own code in this cell
potassium_level = 4
if potassium_level > 8.5 :
    print("You will die soon! God bless you.")

# %% [markdown]
# ## 🍋🍋🍋
# 2.Kami wrote the program below to ensure that the following fraction does not have a zero denominator.
# Can you modify the following code to handle Zero with (Try... Except)?
# $$\frac{a}{b}  \rightarrow a=1  \rightarrow \frac{1}{b} $$

# %%
# Write your own code in this cell
a, b = 1, int(input("Enter denominator:"))
c = ( a / b ) if b != 0 else "In mathematics, dividing a number by zero is undefined."
print(c)

# %% [markdown]
# ## 🍋🍋
# 3.Sasan wants to print all 8mer pieces of DNA. But unfortunately he faced with an error. Please fix the error and use (Try... Except) to print the following sentence if the similar error occurs again : **"Failure is simply a few errors in judgment, repeated every day."**

# %%
# Write your own code in this cell
DNA = ["AAATAAAG", "AATAAAGC", "ATAAAGCA",
       "TAAAGCAT", "AAAGCATC", "AAGCATCC",
       "AGCATCCC", "GCATCCCG", "CATCCCGC",
       "ATCCCGCA"]
for i in range(len(DNA)+1):
    kmer =(DNA[i])
    print(kmer)
# Out:
# AAATAAAG
# AATAAAGC
# ATAAAGCA
# TAAAGCAT
# AAAGCATC
# AAGCATCC
# AGCATCCC
# GCATCCCG
# CATCCCGC
# ATCCCGCA
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1644/3705942749.py in <module>
#       5        "ATCCCGCA"]
#       6 for i in range(len(DNA)+1):
# ----> 7     kmer =(DNA[i])
#       8     print(kmer)
#
# IndexError: list index out of range

# %% [markdown]
# ## 🍋
# 4.Sina has nearly a thousand files in this path **```./Files/errors```** that wants to store the contents of all of them in one variable. The files are named as follows.
# $$file001.txt   \rightarrow   file999.txt$$
#
# Help him read the contents of all the files and if the program can not find a file, print the name of that file but do not stop the code.
# Finally, print the count of the files that code did not find and send a proud message that the **"process is completed"**. The program should also be able to print this sentence if there is no error in the program: **"Success is the sum of small efforts - repeated day in and day out."**

# %%
# Write your own code in this cell
from  pathlib import Path
p = Path('./Files/errors')

# %% [markdown]
# ## 🍋
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5.Create a class called **Pawn** so that it has a method called **.Move()**, and if Soldier move is unauthorized, **```PawnMoveError:```** will appear.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the picture above, The pawn has entered at **e4**.
# $$WhitePawn.move(e4)$$

# %%
#### Write your own code in this cell
class PawnMoveError




class Pawn:
    def __init__(self, initial_position)
        self.position = initial_position
    
    def move(self, destination)

    
    
if __main__ :
    white_pawn = Pawn("c2")
    while True:
        x = input("Enter Next Move :")
        if x == "0" : break
        white_pawn.move(x)
        print(white_pawn.position)

# %% [markdown]
# ## 🍋🍋🍋
# 6.Modify the following code so that **```ArithmeticError```** occurs, then handle this error with **try** ... **except** syntax.

# %%
# Write your own code in this cell
result = 10/2  
print (result)

try:
    pass
except:
    print("An arithmetic exception has occurred!")

# %% [markdown]
# ## 🍋🍋🍋
# 7.Modify the following code so that  **```AssertionError```** occurs.

# %%
# Write your own code in this cell
x = 11
assert x>10, 'The assertion failed'

# %% [markdown]
# ## 🍋
# 8.**Can you explain why the following assert Syntax is unacceptable?**

# %%
# Write your own code in this cell
def is_admin(username, password):
    if username == "admin" and password == "admin":
        return True
    return False

assert is_admin("admin", "admin"), 'You are not allowed!'

# %% [markdown]
# ## 🍋🍋🍋
# 9.Modify the following code so that **```AttributeError```** occurs, then handle this error with **try** ... **except** syntax.

# %%
# Write your own code in this cell
class Car(object):
    def __init__(self, name):
        self.name = name
        
mycar = Car("Benz")
print(mycar.name)

# %% [markdown]
# ## 🍋🍋🍋
# 10.Modify the following code so that **``` ImportError```** occurs.

# %%
# Write your own code in this cell
import numpy as np
from pathlib import Path

# %% [markdown]
# ## 🍋🍋🍋
# 11.Modify the following code so that **```TypeError```** occurs, then handle this error with **try** ... **except** syntax.

# %%
# Write your own code in this cell
x = ("Hello ") + "World!"
print(x)

# %% [markdown]
# ## 🍋
# 12.Modify the following code so that **```FileExistsError```** occurs, then handle this error with **try** ... **except** syntax.

# %%
# Write your own code in this cell
with open('./Files/errors/file001.txt' ,'r') as f: 
    for line in f.readlines():
        print(line)
