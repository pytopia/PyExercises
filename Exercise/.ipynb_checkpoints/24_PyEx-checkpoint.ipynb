# %% [markdown]
# # 24 - Advanced Exercises
#
# *   JSON

# %%
# Run this cell to import the main class:
import json

# %% [markdown]
# ## 🍿🍿🍿
# 1.Create a Python program that will convert a Python object to JSON data.

# %%
# Write your own code in this cell
myobj = {"_id":"e7bee06e34cf468399c3bf82d8e766f4",
            "cals_per100grams":"89",
            "category_id":"97e8f81e5c0a44bbbbd527d46477281b",
            "kj_per100grams":"374",
            "name":"Banana",
            "per100grams":"100",
            "in_the_market":True}

json_obj = 
print("\nJSON data:")
print(json_obj)
# Out:
# JSON data:
# {"_id": "e7bee06e34cf468399c3bf82d8e766f4", "cals_per100grams": "89", "category_id": "97e8f81e5c0a44bbbbd527d46477281b", "kj_per100grams": "374", "name": "Banana", "per100grams": "100", "in_the_market": true}

# %% [markdown]
# ## 🍿🍿🍿
# 2.Create a Python code that will transform JSON data to Python objects.

# %%
# Write your own code in this cell
json_data = '{"cals_per100grams": "89", "kj_per100grams": "374", "name": "Banana"}'
myobj = 
print("Name: ", myobj[])
print("Calories per 100 grams: ", myobj[])
print("Kilojoules per hundred grams : ", myobj[])
# Out:
# Name:  Banana
# Calories per 100 grams:  89
# Kilojoules per hundred grams :  374

# %% [markdown]
# ## 🍿🍿🍿
# 3.Make a Python program that converts Python objects to JSON data.
# Print out all of the values.

# %%
# Write your own code in this cell
mydict =  {"cals_per100grams": "89", "kj_per100grams": "374", "name": "Banana"}
mylist =  ["Apple", "Orange", "Banana"]
mystr =  "Math doesn’t take sides. It doesn’t judge"
myint =  999_999_000_001
myfloat =  3.14159
mybool =  True
mynone =  None

json_obj =  
json_array =  
json_string =  
json_int_number =  
json_float_number =  
json_bool =  
json_null =  
print("json object : ", )
print("jason array : ", )
print("json string : ", )
print("json number1 : ", )
print("json number2 : ", )
print("json bool : ", )
print("json null ; ", )

# %% [markdown]
# ## 🍿🍿🍿

# %%
# Write your own code in this cell

# %% [markdown]
# ## 🍿🍿🍿

# %%
# Write your own code in this cell

# %% [markdown]
# ## 🍿🍿🍿

# %%
# Write your own code in this cell

# %% [markdown]
# ## 🍿🍿🍿

# %%
# Write your own code in this cell

# %% [markdown]
# ## 🍿🍿🍿

# %%
# Write your own code in this cell

# %% [markdown]
# ## 🍿🍿🍿

# %%
# Write your own code in this cell

# %% [markdown]
# ## 🍿🍿🍿

# %%
# Write your own code in this cell

# %% [markdown]
# ## 🍿🍿🍿

# %%
# Write your own code in this cell
import requests

url = "https://food-calories1.p.rapidapi.com/foods/all"

headers = {
    'x-rapidapi-host': "food-calories1.p.rapidapi.com",
    'x-rapidapi-key': "b06756d142msh2d78abbf6e25847p10ffa5jsna04de7af2118"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# [{"_id":"435a1b6f65f749f4b574da0e45dcbfed","cals_per100grams":"62","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"260","name":"Applesauce","per100grams":"100"},{"_id":"1b5ef1d623184f7fa6ce53fe3acc2fcf","cals_per100grams":"48","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"202","name":"Canned Apricots","per100grams":"100"},{"_id":"1d57ea3c6e7440109f4b81111dda8867","cals_per100grams":"92","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"386","name":"Canned Blackberries","per100grams":"100"},{"_id":"5003621c515540b782059637b2cc0ded","cals_per100grams":"88","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"370","name":"Canned Blueberries","per100grams":"100"},{"_id":"64d86b35fc114d60a12345b83594d0a0","cals_per100grams":"54","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"227","name":"Canned Cherries","per100grams":"100"},{"_id":"558c3d38eb7b4dfeba2356ef9f200221","cals_per100grams":"178","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"748","name":"Canned Cranberries","per100grams":"100"},{"_id":"f4c9cec0b8924a1c82b2c6fdf8963a8f","cals_per100grams":"53","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"223","name":"Canned Crushed Pineapple","per100grams":"100"},{"_id":"f5ce7f7bde684eefae1f0e0487314e93","cals_per100grams":"107","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"449","name":"Canned Figs","per100grams":"100"},{"_id":"23b1be9243aa4f97976b01776e8b78b8","cals_per100grams":"81","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"340","name":"Canned Fruit Cocktail","per100grams":"100"},{"_id":"882eb0cc567f410d89cef838723077be","cals_per100grams":"50","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"210","name":"Canned Fruit Salad","per100grams":"100"},{"_id":"91011bb3ddb945e7925410386ab02f9f","cals_per100grams":"73","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"307","name":"Canned Gooseberries","per100grams":"100"},{"_id":"a28be314584b454bb98c0dbd93c6d7ed","cals_per100grams":"37","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"155","name":"Canned Grapefruit","per100grams":"100"},{"_id":"3876f0e7656a40b29fd49fa2da17085a","cals_per100grams":"76","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"319","name":"Canned Grapes","per100grams":"100"},{"_id":"3b99945bbcf8410bad86dc5e94351cd7","cals_per100grams":"71","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"298","name":"Canned Mandarin Oranges","per100grams":"100"},{"_id":"58a7e816b26a4250a6a58db44eaca44f","cals_per100grams":"65","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"273","name":"Canned Mango","per100grams":"100"},{"_id":"97aa8c23e9974a679f0298ce3b558185","cals_per100grams":"73","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"307","name":"Canned Mangosteen","per100grams":"100"},{"_id":"3c67eebdc6ce4629b33caa2d96b0a35f","cals_per100grams":"71","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"298","name":"Canned Mixed Fruit","per100grams":"100"},{"_id":"d86d73e60acb4fa992704fc036d92623","cals_per100grams":"81","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"340","name":"Canned Morello Cherries","per100grams":"100"},{"_id":"89c1bc5c2a8640e891d78bd993bfb12e","cals_per100grams":"62","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"260","name":"Canned Oranges","per100grams":"100"},{"_id":"9ba7ac02e68c48c99e6af2ef59087940","cals_per100grams":"54","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"227","name":"Canned Peaches","per100grams":"100"},{"_id":"cff83f2bb1dc47979eb0a3b96e1edb84","cals_per100grams":"35","category_id":"b7ed5b1c512a46538eb69f83dba3e52b","kj_per100grams":"147","name":"Canned Pears","per100grams":"100"},{"_id":"234c1cd482d84825a709fe3fc14bd8d8","cals_per100grams":"60","category_id":"b7ed5b1c512a4653 ...

# %% [markdown]
# ## 🍿🍿🍿
